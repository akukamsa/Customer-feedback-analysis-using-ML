# %%
str=input()
d={}
for i in str:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
print(d)
# Out:
# Akashja asdfasaSD:asd
# {'A': 1, 'k': 1, 'a': 6, 's': 4, 'h': 1, 'j': 1, ' ': 1, 'd': 2, 'f': 1, 'S': 1, 'D': 1, ':': 1}

# %%
# %matplotlib inline
x=[10,20,30]
y=[1,2,3]
plt.plot(x,y,'r')
